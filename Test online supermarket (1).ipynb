# %%
punkte = 0

print("Willkommen im virtuellen Supermarkt! Du kannst dir Lebensmittel aussuchen und in den Warenkorb legen. Nach Abschluss des Einkaufs, werden die Lebensmittel innerhalb eines Tages geliefert")
your_name=input('Dein Name: ')
your_city=input('Deine Stadt: ')
your_country=input('Dein Land: ')

print("Füge einfach die Lebensmittel hinzu, die du gerne möchtest. Am Ende wird dein Einkauf nach Nachhaltigkeit bewertet")

#erstes Regal: Obst
print("Obstregal")
print("1)" o1.name, o1.Herkunft)
print("2) Banane")
print("3) Orange")
antwort = input("Eingabe: ")
if antwort == "1" :
    punkte +=3
    print("Du hast erfolgreich einen Apfel in den Warenkorb gelegt")
elif antwort == "2" :
    punkte +=2
    print("Du hast erfolgreich eine Banane in den Warenkorb gelegt")
else:
    punkte +=1
    print("Du hast erfolgreich eine Orange in den Warenkorb gelegt")
    
class Obst:
    o1.Name = "Apfel"
    o1.Herkunft = "Deutschland"
    o1.Nachhaltigkeit  #hier liste von Apfel einfügen
